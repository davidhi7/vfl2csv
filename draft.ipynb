# %%
import openpyxl
import pandas as pd

# %%
file = openpyxl.load_workbook(filename='res/daten.xlsx', read_only=True)
print('Liste von Tabellen:', ', '.join(file.sheetnames))

sample_sheet_name = '09201_518a2'
sample_sheet = file[sample_sheet_name]
print(f'Metadaten Tabelle {sample_sheet_name}:')

# extract metadata
metadata = dict()
for row in sample_sheet.iter_rows(min_row=5, max_row=11, min_col=1, max_col=1, values_only=True):
    key, value = row[0].split(':')
    metadata[key.strip()] = value.strip()
print(metadata)
# Out:
# Liste von Tabellen: 09201_518a2, 09202_536a3, 09702_P1, 09702_P2, 09702_P3, 09702_P4, 09703_P1, 09703_P2, 09703_P3, 11201_P11, 11201_P12, 11201_P13, 11201_P14, 11201_P21, 11201_P22, 11201_P23, 11201_P24
# Metadaten Tabelle 09201_518a2:
# {'Forstamt': '5622   Mühlhausen', 'Revier': 'Langula', 'Versuch': '09201', 'Parzelle': '01', 'Teilfläche': '518 a2', 'Standort': 'Uff-R2', 'Höhenlage': '426'}

# %%
# create pandas dataframe
df = pd.read_excel('res/daten.xlsx', sheet_name = sample_sheet_name, header = list(range(0, 4)), skiprows = 13)
df.columns = [ 'Bestandeseinheit', 'Baumart', 'Baumnummer', *[ f'{ multi_index[1] }_{ multi_index[0].year }' for multi_index in df.columns[3:] ] ]
df = df.drop(columns='Bestandeseinheit')
df
# Out:
#     Baumart  Baumnummer  D_1960  Aus_1960  H_1960  D_1967  Aus_1967  H_1967  \
# 0       Hbu           1     9.5       NaN     NaN    13.1       NaN     NaN
# 1        Es           2    21.6       NaN     NaN    24.3       NaN     NaN
# 2        Bu           3    21.6       NaN     NaN    23.8       7.0    21.2
# 3        Ah           4    30.3       NaN     NaN    32.1       NaN     NaN
# 4        Es           5    34.5       NaN    28.0    36.9       NaN     NaN
# ..      ...         ...     ...       ...     ...     ...       ...     ...
# 550      Bu       91606     8.0       NaN     NaN     9.9       NaN     NaN
# 551      Bu       91607     7.0       NaN     NaN     7.3       NaN     NaN
# 552      Bu       91608     6.8       NaN     NaN     7.2       NaN     NaN
# 553      Bu       91609     8.8       NaN     NaN     9.6       NaN     NaN
# 554      Bu       91610     8.0       NaN     NaN     8.5       NaN     NaN
#
#      D_1976  Aus_1976  ...  H_2003  D_2006  Aus_2006  H_2006  D_2010  \
# 0      18.2       NaN  ...     NaN    20.6       4.0     NaN     NaN
# 1      29.5       NaN  ...    30.5    47.2       NaN    33.0    48.9
# 2       NaN       NaN  ...     NaN     NaN       NaN     NaN     NaN
# 3      32.8       NaN  ...    27.0    38.4       NaN    31.0    38.6
# 4      40.6       7.0  ...     NaN     NaN       NaN     NaN     NaN
# ..      ...       ...  ...     ...     ...       ...     ...     ...
# 550    15.5       NaN  ...     NaN    33.1       3.0     NaN     NaN
# 551    10.6       NaN  ...     NaN    17.8       NaN     NaN    18.3
# 552     9.9       NaN  ...     NaN    11.9       NaN     NaN    12.2
# 553    13.3       NaN  ...     NaN    16.2       NaN     NaN    16.3
# 554    13.4       NaN  ...     NaN    23.6       NaN     NaN    25.0
#
#      Aus_2010  H_2010  D_2016  Aus_2016  H_2016
# 0         NaN     NaN     NaN       NaN     NaN
# 1         NaN     NaN    50.5       NaN     NaN
# 2         NaN     NaN     NaN       NaN     NaN
# 3         NaN     NaN    39.8       NaN     NaN
# 4         NaN     NaN     NaN       NaN     NaN
# ..        ...     ...     ...       ...     ...
# 550       NaN     NaN     NaN       NaN     NaN
# 551       NaN     NaN    19.7       NaN     NaN
# 552       NaN     NaN    13.2       NaN     NaN
# 553       NaN     NaN    17.3       NaN     NaN
# 554       NaN     NaN    27.7       NaN     NaN
#
# [555 rows x 29 columns]

# %%
with open(f'res/{sample_sheet_name}.csv', 'w') as f:
    df.to_csv(f, index=False, na_rep='NA')
